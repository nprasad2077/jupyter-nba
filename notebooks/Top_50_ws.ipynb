# %% [markdown]
# # Top 50 NBA Players by Win Shares since 1993

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

import plotly.graph_objs as go
import matplotlib.pyplot as plt
import numpy as np
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
import pandas as pd
import plotly.express as px

# %% [markdown]
# ## Fetch data from GraphQL endpoint

# %%
# Setup the transport and client
_transport = RequestsHTTPTransport(
    url='http://209.38.172.107/graphql/',
    use_json=True,
)

client = Client(
    transport = _transport,
    fetch_schema_from_transport=True,
)

# Define Query
query = gql('''
query playerWinSharesTop {
  playerAdvancedAll(ordering: "-win_shares", limit: 50) {
    playerName
    position
    team
    season
    minutesPlayed
    games
    box
    winShares
    id
  }
}
''')

# Execute and store response

response = client.execute(query)
# Out:
# {'playerAdvancedAll': [{'playerName': 'Michael Jordan*', 'position': 'SG', 'team': 'CHI', 'season': 1996, 'minutesPlayed': 3090, 'games': 82, 'box': '10.5', 'winShares': '20.4', 'id': '16287'}, {'playerName': 'LeBron James', 'position': 'SF', 'team': 'CLE', 'season': 2009, 'minutesPlayed': 3054, 'games': 81, 'box': '13.2', 'winShares': '20.3', 'id': '9254'}, {'playerName': 'David Robinson*', 'position': 'C', 'team': 'SAS', 'season': 1994, 'minutesPlayed': 3241, 'games': 80, 'box': '11.9', 'winShares': '20.0', 'id': '17422'}, {'playerName': 'LeBron James', 'position': 'PF', 'team': 'MIA', 'season': 2013, 'minutesPlayed': 2877, 'games': 76, 'box': '11.7', 'winShares': '19.3', 'id': '6910'}, {'playerName': 'Kevin Durant', 'position': 'SF', 'team': 'OKC', 'season': 2014, 'minutesPlayed': 3122, 'games': 81, 'box': '10.2', 'winShares': '19.2', 'id': '6229'}, {'playerName': 'Kevin Durant', 'position': 'SF', 'team': 'OKC', 'season': 2013, 'minutesPlayed': 3119, 'games': 81, 'box': '9.3', 'winShares': '18.9', 'id': '6803'}, {'playerName': "Shaquille O'Neal*", 'position': 'C', 'team': 'LAL', 'season': 2000, 'minutesPlayed': 3163, 'games': 79, 'box': '9.3', 'winShares': '18.6', 'id': '14264'}, {'playerName': 'LeBron James', 'position': 'SF', 'team': 'CLE', 'season': 2010, 'minutesPlayed': 2966, 'games': 76, 'box': '11.8', 'winShares': '18.5', 'id': '8689'}, {'playerName': 'David Robinson*', 'position': 'C', 'team': 'SAS', 'season': 1996, 'minutesPlayed': 3019, 'games': 82, 'box': '8.9', 'winShares': '18.3', 'id': '16456'}, {'playerName': 'Chris Paul', 'position': 'PG', 'team': 'NOH', 'season': 2009, 'minutesPlayed': 3002, 'games': 78, 'box': '11.0', 'winShares': '18.3', 'id': '9395'}, {'playerName': 'Michael Jordan*', 'position': 'SG', 'team': 'CHI', 'season': 1997, 'minutesPlayed': 3106, 'games': 82, 'box': '8.9', 'winShares': '18.3', 'id': '15734'}, {'playerName': 'Kevin Garnett*', 'position': 'PF', 'team': 'MIN', 'season': 2004, 'minutesPlayed': 3231, 'games': 82, 'box': '10.2', 'winShares': '18.3', 'id': '12007'}, {'playerName': 'Stephen Curry', 'position': 'PG', 'team': 'GSW', 'season': 2016, 'minutesPlayed': 2700, 'games': 79, 'box': '11.9', 'winShares': '17.9', 'id': '4931'}, {'playerName': 'Chris Paul', 'position': 'PG', 'team': 'NOH', 'season': 2008, 'minutesPlayed': 3006, 'games': 80, 'box': '10.4', 'winShares': '17.8', 'id': '9985'}, {'playerName': 'Tim Duncan*', 'position': 'PF', 'team': 'SAS', 'season': 2002, 'minutesPlayed': 3329, 'games': 82, 'box': '7.6', 'winShares': '17.8', 'id': '13029'}, {'playerName': 'Dirk Nowitzki*', 'position': 'PF', 'team': 'DAL', 'season': 2006, 'minutesPlayed': 3089, 'games': 81, 'box': '8.1', 'winShares': '17.7', 'id': '11041'}, {'playerName': 'David Robinson*', 'position': 'C', 'team': 'SAS', 'season': 1995, 'minutesPlayed': 3074, 'games': 81, 'box': '9.2', 'winShares': '17.5', 'id': '16939'}, {'playerName': 'Michael Jordan*', 'position': 'SG', 'team': 'CHI', 'season': 1993, 'minutesPlayed': 3067, 'games': 78, 'box': '11.2', 'winShares': '17.2', 'id': '17728'}, {'playerName': "Shaquille O'Neal*", 'position': 'C', 'team': 'ORL', 'season': 1994, 'minutesPlayed': 3224, 'games': 81, 'box': '6.8', 'winShares': '16.9', 'id': '17376'}, {'playerName': 'Karl Malone*', 'position': 'PF', 'team': 'UTA', 'season': 1997, 'minutesPlayed': 2998, 'games': 82, 'box': '8.3', 'winShares': '16.7', 'id': '15781'}, {'playerName': 'Tim Duncan*', 'position': 'PF', 'team': 'SAS', 'season': 2003, 'minutesPlayed': 3181, 'games': 81, 'box': '7.6', 'winShares': '16.5', 'id': '12531'}, {'playerName': 'Karl Malone*', 'position': 'PF', 'team': 'UTA', 'season': 1998, 'minutesPlayed': 3030, 'games': 81, 'box': '7.3', 'winShares': '16.4', 'id': '15206'}, {'playerName': 'James Harden', 'position': 'SG', 'team': 'HOU', 'season': 2015, 'minutesPlayed': 2981, 'games': 81, 'box': '8.8', 'winShares': '16.4', 'id': '5645'}, {'playerName': 'Dirk Nowitzki*', 'position': 'PF', 'team': 'DAL', 'season': 2007, 'minutesPlayed': 2820, 'games' ...

# %% [markdown]
# ## Sort JSON data into a Pandas Data Frame and sort values.

# %%
df = pd.DataFrame(response['playerAdvancedAll'])

df_sorted = df.sort_values('winShares', ascending=False).head(50)


# Head option displays number of players in table. 
df_sorted.head(20)
# Out:
#            playerName position team  season  minutesPlayed  games   box  \
# 0     Michael Jordan*       SG  CHI    1996           3090     82  10.5
# 1        LeBron James       SF  CLE    2009           3054     81  13.2
# 2     David Robinson*        C  SAS    1994           3241     80  11.9
# 3        LeBron James       PF  MIA    2013           2877     76  11.7
# 4        Kevin Durant       SF  OKC    2014           3122     81  10.2
# 5        Kevin Durant       SF  OKC    2013           3119     81   9.3
# 6   Shaquille O'Neal*        C  LAL    2000           3163     79   9.3
# 7        LeBron James       SF  CLE    2010           2966     76  11.8
# 8     David Robinson*        C  SAS    1996           3019     82   8.9
# 9          Chris Paul       PG  NOH    2009           3002     78  11.0
# 10    Michael Jordan*       SG  CHI    1997           3106     82   8.9
# 11     Kevin Garnett*       PF  MIN    2004           3231     82  10.2
# 12      Stephen Curry       PG  GSW    2016           2700     79  11.9
# 14        Tim Duncan*       PF  SAS    2002           3329     82   7.6
# 13         Chris Paul       PG  NOH    2008           3006     80  10.4
# 15     Dirk Nowitzki*       PF  DAL    2006           3089     81   8.1
# 16    David Robinson*        C  SAS    1995           3074     81   9.2
# 17    Michael Jordan*       SG  CHI    1993           3067     78  11.2
# 18  Shaquille O'Neal*        C  ORL    1994           3224     81   6.8
# 19       Karl Malone*       PF  UTA    1997           2998     82   8.3
#
#    winShares     id
# 0       20.4  16287
# 1       20.3   9254
# 2       20.0  17422
# 3       19.3   6910
# 4       19.2   6229
# 5       18.9   6803
# 6       18.6  14264
# 7       18.5   8689
# 8       18.3  16456
# 9       18.3   9395
# 10      18.3  15734
# 11      18.3  12007
# 12      17.9   4931
# 14      17.8  13029
# 13      17.8   9985
# 15      17.7  11041
# 16      17.5  16939
# 17      17.2  17728
# 18      16.9  17376
# 19      16.7  15781
