# %% [markdown]
# # Top 50 NBA Players by Win Shares since 1993

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

import plotly.graph_objs as go
import matplotlib.pyplot as plt
import numpy as np
from gql import gql, Client
from gql.transport.requests import RequestsHTTPTransport
import pandas as pd
import plotly.express as px

# %% [markdown]
# ## Fetch data from GraphQL endpoint

# %%
# Setup the transport and client
_transport = RequestsHTTPTransport(
    url='http://209.38.172.107/graphql/',
    use_json=True,
)

client = Client(
    transport = _transport,
    fetch_schema_from_transport=True,
)

# Define Query
query = gql('''
query playerWinSharesTop {
  playerAdvancedAll(ordering: "-win_shares", limit: 50) {
    playerName
    position
    team
    season
    minutesPlayed
    games
    box
    winShares
    id
  }
}
''')

# Execute and store response

response = client.execute(query)

# %% [markdown]
# ## Sort JSON data into a Pandas Data Frame and sort values.

# %%
df = pd.DataFrame(response['playerAdvancedAll'])

df_sorted = df.sort_values('winShares', ascending=False).head(50)


# Head option displays number of players in table. 
df_sorted.head(50)
# Out:
#            playerName position team  season  minutesPlayed  games   box  \
# 0     Michael Jordan*       SG  CHI    1996           3090     82  10.5
# 1        LeBron James       SF  CLE    2009           3054     81  13.2
# 2     David Robinson*        C  SAS    1994           3241     80  11.9
# 3        LeBron James       PF  MIA    2013           2877     76  11.7
# 4        Kevin Durant       SF  OKC    2014           3122     81  10.2
# 5        Kevin Durant       SF  OKC    2013           3119     81   9.3
# 6   Shaquille O'Neal*        C  LAL    2000           3163     79   9.3
# 7        LeBron James       SF  CLE    2010           2966     76  11.8
# 8     David Robinson*        C  SAS    1996           3019     82   8.9
# 9          Chris Paul       PG  NOH    2009           3002     78  11.0
# 10    Michael Jordan*       SG  CHI    1997           3106     82   8.9
# 11     Kevin Garnett*       PF  MIN    2004           3231     82  10.2
# 12      Stephen Curry       PG  GSW    2016           2700     79  11.9
# 14        Tim Duncan*       PF  SAS    2002           3329     82   7.6
# 13         Chris Paul       PG  NOH    2008           3006     80  10.4
# 15     Dirk Nowitzki*       PF  DAL    2006           3089     81   8.1
# 16    David Robinson*        C  SAS    1995           3074     81   9.2
# 17    Michael Jordan*       SG  CHI    1993           3067     78  11.2
# 18  Shaquille O'Neal*        C  ORL    1994           3224     81   6.8
# 19       Karl Malone*       PF  UTA    1997           2998     82   8.3
# 20        Tim Duncan*       PF  SAS    2003           3181     81   7.6
# 21       Karl Malone*       PF  UTA    1998           3030     81   7.3
# 22       James Harden       SG  HOU    2015           2981     81   8.8
# 23     Dirk Nowitzki*       PF  DAL    2007           2820     78   8.3
# 24       LeBron James       SF  CLE    2006           3361     79   9.1
# 28     Dirk Nowitzki*       PF  DAL    2003           3117     80   7.2
# 29     Kevin Garnett*       PF  MIN    2005           3121     82   9.5
# 25     Tracy McGrady*       SG  ORL    2003           2954     75  10.5
# 27         Chris Paul       PG  LAC    2015           2857     82   8.0
# 26       Kevin Durant       SF  OKC    2010           3239     82   7.1
# 30       LeBron James       PF  MIA    2014           2902     77   8.8
# 31    Michael Jordan*       SG  CHI    1998           3181     82   6.9
# 32   Hakeem Olajuwon*        C  HOU    1993           3242     82   7.5
# 33      Stephen Curry       PG  GSW    2015           2613     80   9.9
# 34     Kevin Garnett*       PF  MIN    2003           3321     82   8.4
# 35       LeBron James       SF  MIA    2011           3063     79   8.1
# 36     Dirk Nowitzki*       PF  DAL    2005           3020     78   7.3
# 37       Nikola Jokić        C  DEN    2021           2488     72  12.1
# 38   Chauncey Billups       PG  DET    2006           2925     81   6.2
# 40       Karl Malone*       PF  UTA    1993           3099     82   7.3
# 39       James Harden       SG  HOU    2018           2551     72   9.9
# 41       Karl Malone*       PF  UTA    2000           2947     82   7.5
# 42       Kobe Bryant*       SG  LAL    2006           3277     80   7.6
# 43       James Harden       PG  HOU    2019           2867     78  11.0
# 44       LeBron James       SF  CLE    2008           3027     75  10.9
# 45       Nikola Jokić        C  DEN    2022           2476     74  13.7
# 46       Karl Malone*       PF  UTA    1996           3113     82   7.0
# 47       James Harden       PG  HOU    2017           2947     81   8.7
# 48       Nikola Jokić        C  DEN    2023           2323     69  13.0
# 49     Kevin Garnett*       PF  MIN    2006           2957     76   7.8
#
#    winShares     id
# 0       20.4  16287
# 1       20.3   9254
# 2       20.0  17422
# 3       19.3   6910
# 4       19.2   6229
# 5       18.9   6803
# 6       18.6  14264
# 7       18.5   8689
# 8       18.3  16456
# 9       18.3   9395
# 10      18.3  15734
# 11      18.3  12007
# 12      17.9   4931
# 14      17.8  13029
# 13      17.8   9985
# 15      17.7  11041
# 16      17.5  16939
# 17      17.2  17728
# 18      16.9  17376
# 19      16.7  15781
# 20      16.5  12531
# 21      16.4  15206
# 22      16.4   5645
# 23      16.3  10502
# 24      16.3  10931
# 28      16.1  12724
# 29      16.1  11428
# 25      16.1  12688
# 27      16.1   5840
# 26      16.1   8553
# 30      15.9   6340
# 31      15.8  15171
# 32      15.8  17817
# 33      15.7   5528
# 34      15.6  12553
# 35      15.6   8090
# 36      15.6  11622
# 37      15.6   1836
# 38      15.5  10729
# 40      15.4  17772
# 39      15.4   3789
# 41      15.3  14211
# 42      15.3  10755
# 43      15.2   3118
# 44      15.2   9838
# 45      15.2   1071
# 46      15.1  16332
# 47      15.0   4431
# 48      14.9    319
# 49      14.9  10856
